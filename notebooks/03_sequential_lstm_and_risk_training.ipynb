# %% [markdown]
# # PyTorch BiLSTM Pilot Action Prediction & Flight Risk Scoring
# ### AI Co-Pilot: Model Training, Cross-Validation & Metric Evaluation
#
# This notebook trains the sequential Bidirectional LSTM with Attention and the Gradient Boosted Risk Regressor.

# %%
from backend.app.ml.train import train_all_models
metrics = train_all_models(num_samples=1200, epochs=10, batch_size=32)
print("Training Complete. Summary:")
print(f"Accuracy: {metrics['action_prediction']['accuracy'] * 100:.2f}%")
print(f"ROC-AUC: {metrics['action_prediction']['roc_auc_ovr']:.4f}")
print(f"Risk R2 Score: {metrics['risk_scoring']['r2_score']:.4f}")
